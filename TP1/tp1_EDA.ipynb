# %% [markdown]
# # Trabajo Práctico Machine Learning: Estadísticas de jugadores NBA

# %% [markdown]
# La National Basketball Association, más conocida simplemente por sus siglas NBA, es una liga de baloncesto profesional que se disputa en Estados Unidos desde 1949. La misma esta rankeada como la mejor liga en el mundo de este deporte. Actualmente, la misma posee 30 equipos que compiten entre ellos.
#
# ![Chicago Bulls vs Utah Jazz 1998](https://i.pinimg.com/564x/75/91/60/75916076b50a451a4c09eb58d3beff11.jpg)

# %% [markdown]
# ## Punto 1. Listado de variables y Selección

# %% [markdown]
# ### Variables que no son tomadas en cuenta

# %% [markdown]
# •**blanl:** Campo en nulo del set de datos. NO, es un error en el dataset que no debe ser tenido en cuenta.<br>
# •**blank2:** Campo en nulo del set de datos. NO, es un error en el dataset que no debe ser tenido en cuenta.<br>
# •**Tm:** hace referencia al “team”, es decir, el equipo para el que juega el jugador. No, al tener el equipo en el que jugará el basquetbolista en la siguiente temporada puede significar data futura.<br>

# %% [markdown]
# ### Variables que si serán tomadas en cuenta

# %% [markdown]
# •**Year:** año de la temporada que se jugó. **No es de entrada**, pero la vamos a utilizar a la hora de entrenar el modelo<br>
# •**Player:** nombre del jugador. **No es de Entrada**, pero la vamos a utilizar a la hora de entrenar el modelo<br>
# •**Age:** edad del jugador.  **Entrada**. La vamos a utilizar porque creemos que es importante la edad cuando hablamos del rendimiento del jugador en la temporada siguiente.<br>
# •**MP:** “Minutes Played” son los minutos en cancha del jugador en la temporada. Si, **entrada**. Es necesaria ya que si un jugador juega más minutos tiene más oportunidades de meter mas puntos.<br>
# •**PER:** “Player Efficiency Rating” es una métrica que suma todos los logros positivos que tuvo el jugador y le resta lo negativo. El resultado es una calificación por minuto del desempeño del jugador. Si, **entrada**. Es un indicador muy bueno de lo que hizo el jugador en la temporada.<br>
# •**TS%:** “True Shooting Percentage” es una medida de la eficiencia de tiro que tiene en cuenta los tiros de campo, los tiros de campo de 3 puntos y los tiros libres. Si, **entrada**. Muy importante, ya que posee gran relevancia a la hora de medir la cantidad de puntos que puede lograr un jugador<br>
# •**ORB%:** “Offensive Rebound Percentage” se refiere al porcentaje de rebotes ofensivos, y se trata de una estimación del porcentaje de rebotes ofensivos que un jugador agarró mientras estaba en la cancha. Básicamente es una medida de cuantos rebotes en ataque agarró el jugador. SI, **entrada**. Pensamos que mientras mas rebotes en ataque haya agarrado el jugador, más oportunidades tiene de realizar puntos.<br>
# •**STL%:** “Steal Percentage” o el porcentaje de robos. Es una estimación de la cantidad de veces que el jugador le robó la pelota a un jugador contrario. SI, **entrada**. Creemos que cuando el jugador le roba la pelota a un jugador del equipo contrario, tiene más posibilidades de terminar la jugada haciendo algún punto.<br>
# •**TOV%:** “Turnover Percentage” o el porcentaje de pérdidas. Pérdidas cometidas por cada 100 posesiones. SI, **entrada**. Creemos que las veces que el jugador perdió la pelota influyen negativamente en la cantidad de puntos que puede realizar.<br>

# %% [markdown]
# •**2P%:** Two Points - Dos Puntos: es el porcentaje de tiros de 2 puntos anotados. Si, **entrada**. Puede influir a la hora de calcular los puntos, ya que, si tiene un gran porcentaje de tiros de 2 puntos anotados, probablemente la temporada siguiente haga más puntos<br>
# •**eFG%:** porcentaje efectivo de tiros de campo anotados, es decir, es la cantidad de tiros de campo anotados, ponderados según su valor respecto a los tiros de campo intentados. SI, **entrada**, ya que consideramos que es una variable importante y a tener en cuenta<br>
# •**FT%:** es el porcentaje de tiros libres anotados. Si, **entrada**, puede influir a la hora de calcular los puntos, ya que, si tiene un gran porcentaje de tiros libres anotados, probablemente la temporada siguiente haga más puntos<br>
# •**PTS:** “Points” o puntos totales realizados por el jugador en la temporada. Si, **entrada**. Los puntos son muy importantes ya que con esta columna podemos definir nuestra variable target.<br>
# •**USG%:** Usage Percentage - Porcentaje de Uso. Intenta medir la importancia de un jugador en el ataque de su equipo. SI, **entrada**.  Creemos que es una variable muy importante, ya que, si el equipo depende mucho del jugador, va a tener mas posibilidades de hacer puntos.<br>
# •**OWS:** Offensive Win Shares - Acciones de victoria ofensivas. Es una métrica que estima la cantidad de victorias que un jugador produce para su equipo debido a su habilidad ofensiva. SI, **entrada**. Creemos que si un jugador tiene un bajo valor OWS quiere decir que no es tan relevante en el ataque, y por ende va a realizar menos puntos. Es un dato que creemos relevante para tener en cuenta.<br>
# •**OBPM:** Offensive Box Plus-Minus - Caja de Mas-Menos Ofensiva: Mide la aportación de un jugador al rendimiento total del equipo a través de sus estadísticas por cada 100 posesiones ofensivas. SI, **entrada**. Porque tiene gran relevancia para calcular el target.<br>
# •**VORP:** Value Over Replacement Player: esta estadística mide el rendimiento de un jugador contra el rendimiento que daría un “jugador medio” de la liga. SI, **entrada**. Creemos que, si un jugador resalta mas que el promedio, es mas probable que haga más puntos<br>

# %% [markdown]
# •**FG%:** Field Goals - Tiros de campo: es el porcentaje de tiros de campo anotados. Si, **entrada**. Puede influir a la hora de calcular los puntos, ya que, si tiene un gran porcentaje de tiros de campo anotados, probablemente la temporada siguiente haga más puntos.<br>
# •**3P%:** Three Points - Tres Puntos: es el porcentaje de tiros de 3 puntos anotados. Si, **entrada**. Puede influir a la hora de calcular los puntos, ya que, si tiene un gran porcentaje de tiros de 3 puntos anotados, probablemente la temporada siguiente haga más puntos.<br>
# •**Pos:** posición que ocupa el jugador en la cancha. Si, **entrada**. Puede influir en la cantidad de puntos de un jugador.<br>
# •**G:** “games”, se refiere a los partidos que jugó el jugador en esa temporada especifica. Si, **entrada**.<br>
# •**Gs:** “Games started” se refiere a los partidos que jugo desde el inicio. Si, **entrada**.<br>
# •**3Par:** “3-Point Attempt Rate” es una tasa de tiros de 3 puntos que intentó el jugador.  Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**FTr:** “Free Throw Rate” es la tasa de tiros libres que realizo el jugador. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**DRB%:** “Defensive Rebound Percentage” porcentaje de cuantas veces el jugador agarró los rebotes estando en defensa. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**DRB:** “Defensive Rebound ” cuantas veces el jugador agarró los rebotes estando en defensa. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**TRB%:** “Total Rebound Percentage” es una estimación del porcentaje de rebotes totales que un jugador agarró mientras estaba en la cancha. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**AST%:** “Assist Percentage” es el porcentaje de asistencias. Se refiere a una estimación del porcentaje de “goles” que un jugador del equipo anotó cuando el jugador le pasó la pelota. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**BLK%:** “Block Percentage” o el porcentaje de bloqueos hace referencia al porcentaje de intentos de gol de campo de dos puntos del oponente bloqueados por el jugador mientras estaba en la cancha. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**2P:** cantidad de dobles acertados por el jugador. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**2PA:** cantidad de dobles intentatdos. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**FT:** “Free Throws” o tirlos libres realizados. NSi, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**FTA:** se refiere a los tiros libres intentados. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**ORB:** “Offensive Rebound”, se refiere a los rebotes ofensivos agarrados por el jugador. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**TRB:** “Total Rebounds”, se refiere al total de rebotes agarrados por el jugador.  Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**AST:** se refiere al total de las asistencias. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**STL:** “Steals” o robos. Se refiere a la cantidad total de robos que realizo el jugador. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**BLK:** cantidad de bloqueos que realizó. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**TOV:** “turnover” o perdidas del balón. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**PF:** “Personal Fouls”, se refiere a los fules personales que realizo el jugador. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**DWS:** Defensive Win Shares - Acciones de victoria Defensivas. Es una métrica que estima la cantidad de victorias que un jugador produce para su equipo debido a su habilidad defensiva. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**WS:** Win Shares - Acciones de victoria. Es una estadística que intenta repartir el crédito por el éxito del equipo entre las personas del equipo. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**WS/48:** Win Shares / 48 - Acciones de victoria / 48. Juzga el impacto de cada jugador si todos jugaron la misma cantidad de minutos; además mide la eficiencia de las contribuciones de un jugador. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**DBPM:** Defensive Box Plus-Minus - Caja de Mas-Menos Defensiva: Mide la aportación de un jugador al rendimiento total del equipo a través de sus estadísticas por cada 100 posesiones defensivas. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**BPM:** Box Plus-Minus - Caja de Mas-Menos: Mide la aportación de un jugador al rendimiento total del equipo a través de sus estadísticas por cada 100 posesiones. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**FG:** Field Goals - Tiros de campo: son los tiros de campo anotados. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**FGA:** Field Goals Attempts - Tiros de campo intentados: son los tiros de campo intentados. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**3P:** Three Points - Tres Puntos: son los tiros de 3 puntos anotados. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>
# •**3PA:** Three Points Attempts - Tres Puntos Intentados: tiros de 3 puntos intentados. Si, **entrada**. Puede influir a la hora de predecir los puntos que va a realizar un jugador en la siguiente temporada.<br>

# %% [markdown]
# ### Variable Target

# %% [markdown]
# Nuestra variable "TARGET" se trata de una columna que no se encuentra en el dataset, sino que la tenemos que generar por código. A dicha variable la decidimos llamar **"morePoints"** ("Mas Puntos").
# <br><br>
# Dicha columna podrá tener solo dos valores **"Yes"/"No"** dependiendo si el jugador hizo mas puntos que la temporada anterior o no.
# Cabe aclarar que si es la 1er temporada del jugador o si una temporada no jugo por algun motivo, se colocará en "Yes" ya que consideramos que al no haber jugado, efectivamente realizó mas puntos.

# %% [markdown]
# ### Transformaciones de las variables de entrada

# %% [markdown]
# Al observar los valores de los datos de entrada que elegimos nos percatamos de que si bien hay algunas variables que no requieren ser normalizadas, hay muchas otras que si lo requieren ya que presentan valores muy altos o diferentes en relación a los restantes (que están entre 0 y 1). Por ejemplo:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Teniendo en cuenta todo esto decidimos aplicar MinMaxScaler de sklearn para normalizar los siguientes datos:
# Age, MP, PER, ORB%, TOV%, STL%, OWS, OBPM, VORP, PTS, USG%.
#
# De esta manera todos los datos quedan entonces comprendidos entre los valores 0 y 1.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import keras
import h5py
import PIL
import seaborn as sns
import plotly
import sklearn_pandas
from IPython.display import Image
from IPython.core.display import HTML 
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Preprocesado de los datos

# %%
# Esta celda lo que hace es obtener el dataset que se encuentra en el repositorio, utilizando un path relativo
path = '..//TP1//Seasons_Stats.csv'
data = pd.read_csv(path)

# %%
# Con esta celda buscamos reducir la cantidad de columnas que posee el dataset, eliminando las columnas que pensamos no son necesarias para realizar la predicción.
columns = ['blanl','blank2', 'Tm']
data = data.drop(columns, axis=1)

# %%
# Antes del año 1980 el dataset posee muchas estadísticas que todavía no se tenian en cuenta y hay muchos valores en NaN.
data[data.Year < 1980].isnull().sum()
# Out:
# Unnamed: 0       0
# Year             0
# Player           0
# Pos              0
# Age              8
# G                0
# GS            5697
# MP             486
# PER            518
# TS%             10
# 3PAr          5697
# FTr             11
# ORB%          3827
# DRB%          3827
# TRB%          3048
# AST%          2064
# STL%          3827
# BLK%          3827
# TOV%          4981
# USG%          4979
# OWS             39
# DWS             39
# WS              39
# WS/48          518
# OBPM          3827
# DBPM          3827
# BPM           3827
# VORP          3827
# FG               0
# FGA              0
# FG%             11
# 3P            5697
# 3PA           5697
# 3P%           5697
# 2P               0
# 2PA              0
# 2P%             11
# eFG%            11
# FT               0
# FTA              0
# FT%            113
# ORB           3827
# DRB           3827
# TRB            312
# AST              0
# STL           3827
# BLK           3827
# ...

# %%
# Después de 1980 hay menos columnas con valores NaN
data[data.Year >= 1980].isnull().sum()
# Out:
# Unnamed: 0    0
# Year          0
# Player        0
# Pos           0
# Age           0
# G             0
# GS            0
# MP            0
# PER           0
# TS%           0
# 3PAr          0
# FTr           0
# ORB%          0
# DRB%          0
# TRB%          0
# AST%          0
# STL%          0
# BLK%          0
# TOV%          0
# USG%          0
# OWS           0
# DWS           0
# WS            0
# WS/48         0
# OBPM          0
# DBPM          0
# BPM           0
# VORP          0
# FG            0
# FGA           0
# FG%           0
# 3P            0
# 3PA           0
# 3P%           0
# 2P            0
# 2PA           0
# 2P%           0
# eFG%          0
# FT            0
# FTA           0
# FT%           0
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# dtype: int64

# %%
# Convertimos el dataset en un dataframe
df = pd.DataFrame(data)

# %%
# Según lo que pudimos determinar analizando el dataset cuando los valores de 3P% son NaN se debe a que en ese año dicho jugador no intentó ningún tiro de tres puntos. 

# Aquí un ejemplo del jugador Shaquille O'Neal, quién entre los años  2003 y 2008 no realizó ningún intento de tres puntos.
jugador = df[df['Player'] == "Shaquille O'Neal*"]
jugador[['Year','Player','Age','3PAr', '3P%']]
# Out:
#          Year             Player   Age   3PAr  3P%
# 11187  1993.0  Shaquille O'Neal*  20.0  0.002  0.0
# 11685  1994.0  Shaquille O'Neal*  21.0  0.001  0.0
# 12136  1995.0  Shaquille O'Neal*  22.0  0.003  0.0
# 12633  1996.0  Shaquille O'Neal*  23.0  0.002  0.5
# 13220  1997.0  Shaquille O'Neal*  24.0  0.004  0.0
# 13743  1998.0  Shaquille O'Neal*  25.0  0.000  NaN
# 14292  1999.0  Shaquille O'Neal*  26.0  0.001  0.0
# 14806  2000.0  Shaquille O'Neal*  27.0  0.001  0.0
# 15330  2001.0  Shaquille O'Neal*  28.0  0.001  0.0
# 15841  2002.0  Shaquille O'Neal*  29.0  0.001  0.0
# 16324  2003.0  Shaquille O'Neal*  30.0  0.000  NaN
# 16874  2004.0  Shaquille O'Neal*  31.0  0.000  NaN
# 17462  2005.0  Shaquille O'Neal*  32.0  0.000  NaN
# 18030  2006.0  Shaquille O'Neal*  33.0  0.000  NaN
# 18572  2007.0  Shaquille O'Neal*  34.0  0.000  NaN
# 19145  2008.0  Shaquille O'Neal*  35.0  0.000  NaN
# 19146  2008.0  Shaquille O'Neal*  35.0  0.000  NaN
# ...

# %%
# En base a esto propusimos colocar estas filas en 0.

df[['3P%','FT%', '2P%', '3PAr', 'FTr', 'FG%', 'eFG%', 'TS%', 'TOV%']] = df[['3P%','FT%', '2P%', '3PAr', 'FTr', 'FG%', 'eFG%', 'TS%', 'TOV%']].fillna(0)
df['GS'] = df['GS'].fillna(32.033531)
# Ejemplo del jugador Shaquille O'Neal con los NaN reemplazados.

jugador = df[df['Player'] == "Shaquille O'Neal*"]
jugador[['Year','Player','Age','3PAr', '3P%']]
# Out:
#          Year             Player   Age   3PAr  3P%
# 11187  1993.0  Shaquille O'Neal*  20.0  0.002  0.0
# 11685  1994.0  Shaquille O'Neal*  21.0  0.001  0.0
# 12136  1995.0  Shaquille O'Neal*  22.0  0.003  0.0
# 12633  1996.0  Shaquille O'Neal*  23.0  0.002  0.5
# 13220  1997.0  Shaquille O'Neal*  24.0  0.004  0.0
# 13743  1998.0  Shaquille O'Neal*  25.0  0.000  0.0
# 14292  1999.0  Shaquille O'Neal*  26.0  0.001  0.0
# 14806  2000.0  Shaquille O'Neal*  27.0  0.001  0.0
# 15330  2001.0  Shaquille O'Neal*  28.0  0.001  0.0
# 15841  2002.0  Shaquille O'Neal*  29.0  0.001  0.0
# 16324  2003.0  Shaquille O'Neal*  30.0  0.000  0.0
# 16874  2004.0  Shaquille O'Neal*  31.0  0.000  0.0
# 17462  2005.0  Shaquille O'Neal*  32.0  0.000  0.0
# 18030  2006.0  Shaquille O'Neal*  33.0  0.000  0.0
# 18572  2007.0  Shaquille O'Neal*  34.0  0.000  0.0
# 19145  2008.0  Shaquille O'Neal*  35.0  0.000  0.0
# 19146  2008.0  Shaquille O'Neal*  35.0  0.000  0.0
# ...

# %%
df[df.Year >= 1980].isnull().sum()
# Out:
# Unnamed: 0    0
# Year          0
# Player        0
# Pos           0
# Age           0
# G             0
# GS            0
# MP            0
# PER           5
# TS%           0
# 3PAr          0
# FTr           0
# ORB%          5
# DRB%          5
# TRB%          5
# AST%          5
# STL%          5
# BLK%          5
# TOV%          0
# USG%          5
# OWS           0
# DWS           0
# WS            0
# WS/48         5
# OBPM          0
# DBPM          0
# BPM           0
# VORP          0
# FG            0
# FGA           0
# FG%           0
# 3P            0
# 3PA           0
# 3P%           0
# 2P            0
# 2PA           0
# 2P%           0
# eFG%          0
# FT            0
# FTA           0
# FT%           0
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# dtype: int64

# %%
# Eliminamos todas las filas de datos que sean anteriores al año 1980. Elegimos este año ya que a partir de aquí se comienzan a tener en cuenta estadísticas como, por ejemplo, los tiros de 3 puntos.
# Esto lo hacemos ya que, antes de ese año, el dataset poseía muchas estadísticas que todavía no se tenian en cuenta y había muchos valores en NaN
data = data.drop(data[data.Year < 1980].index, axis=0)
# Además, eliminamos todos los datos en NaN para evitar inconsistencias en el dataset.
data = data.dropna()

#Con esta linea mostramos todas las columnas del dataset
pd.set_option('display.max_columns', 100)

# %%
df = pd.DataFrame(data)

# %%
#El data set cuenta con una fila por jugador que sumariza su desempeño anual si el mismo jugó en más de un equipo en la misma temporada; por lo que decidimos quedarnos con esta primer fila y eliminar las demás para tener un resumen de su temporada completa y simplificar así el dataset.
jugador = df[df['Player'] == "Shaquille O'Neal*"]
display(jugador)

#Como se puede observar en la imagen para la columna "Tm" (Team) en 1982 existe el valor 'TOT' el cuál se refiere al total de partidos jugados en San Antonio Spurs y Cleveland Cavaliers.
# Out:
#        Unnamed: 0    Year             Player Pos   Age     G    GS      MP  \
# 11187       11187  1993.0  Shaquille O'Neal*   C  20.0  81.0  81.0  3071.0
# 11685       11685  1994.0  Shaquille O'Neal*   C  21.0  81.0  81.0  3224.0
# 12136       12136  1995.0  Shaquille O'Neal*   C  22.0  79.0  79.0  2923.0
# 12633       12633  1996.0  Shaquille O'Neal*   C  23.0  54.0  52.0  1946.0
# 13220       13220  1997.0  Shaquille O'Neal*   C  24.0  51.0  51.0  1941.0
# 13743       13743  1998.0  Shaquille O'Neal*   C  25.0  60.0  57.0  2175.0
# 14292       14292  1999.0  Shaquille O'Neal*   C  26.0  49.0  49.0  1705.0
# 14806       14806  2000.0  Shaquille O'Neal*   C  27.0  79.0  79.0  3163.0
# 15330       15330  2001.0  Shaquille O'Neal*   C  28.0  74.0  74.0  2924.0
# 15841       15841  2002.0  Shaquille O'Neal*   C  29.0  67.0  66.0  2422.0
# 16324       16324  2003.0  Shaquille O'Neal*   C  30.0  67.0  66.0  2535.0
# ...

# %%
# Este celda elimina los años que figuran mas de una vez para un mismo jugador.
df = df.drop_duplicates(subset=['Player','Year'])

# %%
# Por lo tanto para el jugador Andres Nocioni (por ejemplo), nos quedaríamos con sus "totales" por temporada.
jugador = df[df['Player'] == 'Blake Griffin']
display(jugador)
# Out:
#        Unnamed: 0    Year         Player Pos   Age     G    GS      MP   PER  \
# 20759       20759  2011.0  Blake Griffin  PF  21.0  82.0  82.0  3112.0  21.9
# 21332       21332  2012.0  Blake Griffin  PF  22.0  66.0  66.0  2392.0  23.4
# 21878       21878  2013.0  Blake Griffin  PF  23.0  80.0  80.0  2598.0  22.4
# 22494       22494  2014.0  Blake Griffin  PF  24.0  80.0  80.0  2863.0  23.9
# 23103       23103  2015.0  Blake Griffin  PF  25.0  67.0  67.0  2356.0  22.8
# 23714       23714  2016.0  Blake Griffin  PF  26.0  35.0  35.0  1170.0  22.1
# 24302       24302  2017.0  Blake Griffin  PF  27.0  61.0  61.0  2076.0  22.7
#
#          TS%   3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  \
# 20759  0.549  0.017  0.505  10.2  26.9  18.6  18.7   1.0   1.1  11.7  27.3
# 21332  0.557  0.016  0.458  10.7  25.1  17.8  16.6   1.2   1.7  10.9  26.6
# 21878  0.572  0.026  0.397   8.7  21.5  15.2  19.9   2.0   1.6  12.8  25.4
# ...

# %%
# Esta celda renombra la primer columna del dataFrame (denominada 'Unnamed: 0') y le setea el nombre de "id"
df = df.rename(columns = {'Unnamed: 0' : 'id'})

# %%
# Con esta celda, creamos la que será nuestra columna TARGET y la llamamos "morePoints" ("Mas Puntos")
# Dicha columna podrá tener solo dos valores "Yes"/"No" dependiendo si el jugador hizo mas puntos que la temporada anterior
# Cabe recalcar que si es la 1er temporada del jugador o si una temporada no jugo por algun motivo, se colocará en "Yes" ya que consideramos que al no haber jugado efectivamente realizó mas puntos.
df.insert(18, 'morePoints', 'No', allow_duplicates = True)

# %%
# Esta es una funcion que realizamos para setear la columna "morePoints"
# Buscamos el año anterior y comparamos los puntos que realizó en ese año y el año actual.
# Si efectivamente hizo mas puntos no hacemos nada, pero si no seteamos la columna en "No"
def funcionSetMorePoints(id):
    auxiliar = df.loc[id]
    temporadaSiguiente = df.loc[(df.Player == auxiliar.Player) & (df.Year == auxiliar.Year  + 1)]      
    if ((not temporadaSiguiente.empty) and (auxiliar.PTS <= temporadaSiguiente.PTS.item())):
        df.loc[df.id == id,'morePoints'] = 'Yes'
    else:
        if temporadaSiguiente.empty:
            df.loc[df.id == id,'morePoints'] = 'None'
    return id

# %%
# Llamamos a la funcion defenida anteriormente
df.id = df.id.apply(funcionSetMorePoints)

# %%
# Con esta linea de codigo podemos buscar cualquier jugador y revisar si la funcion anterior seteó los datos correctamente.
jugador = df[df['Player'] == 'Michael Jordan*']
jugador[['Year','Player','Age','PTS','morePoints']]
# Out:
#          Year           Player   Age     PTS morePoints
# 7716   1985.0  Michael Jordan*  21.0  2313.0         No
# 8094   1986.0  Michael Jordan*  22.0   408.0        Yes
# 8469   1987.0  Michael Jordan*  23.0  3041.0         No
# 8869   1988.0  Michael Jordan*  24.0  2868.0         No
# 9297   1989.0  Michael Jordan*  25.0  2633.0        Yes
# 9747   1990.0  Michael Jordan*  26.0  2753.0         No
# 10212  1991.0  Michael Jordan*  27.0  2580.0         No
# 10666  1992.0  Michael Jordan*  28.0  2404.0        Yes
# 11106  1993.0  Michael Jordan*  29.0  2541.0       None
# 12048  1995.0  Michael Jordan*  31.0   457.0        Yes
# 12528  1996.0  Michael Jordan*  32.0  2491.0         No
# 13096  1997.0  Michael Jordan*  33.0  2431.0         No
# 13654  1998.0  Michael Jordan*  34.0  2357.0       None
# 15751  2002.0  Michael Jordan*  38.0  1375.0        Yes
# 16240  2003.0  Michael Jordan*  39.0  1640.0       None

# %%
df = df[df['morePoints'] != 'None']
display(df)
# Out:
#           id    Year            Player Pos   Age     G    GS      MP   PER  \
# 5730    5730  1980.0   Tiny Archibald*  PG  31.0  80.0  80.0  2864.0  15.3
# 5748    5748  1980.0       Larry Bird*  PF  23.0  82.0  82.0  2955.0  20.5
# 5781    5781  1980.0         M.L. Carr  SF  29.0  82.0   7.0  1994.0  14.6
# 5835    5835  1980.0        Chris Ford  SG  31.0  73.0  73.0  2115.0  13.0
# 5867    5867  1980.0  Gerald Henderson  PG  24.0  76.0   2.0  1061.0  12.7
# ...      ...     ...               ...  ..   ...   ...   ...     ...   ...
# 24089  24089  2016.0       James Young  SG  20.0  29.0   0.0   199.0   3.6
# 24090  24090  2016.0         Joe Young  PG  23.0  41.0   0.0   384.0   9.9
# 24091  24091  2016.0        Nick Young  SG  30.0  54.0   2.0  1033.0   9.1
# 24092  24092  2016.0    Thaddeus Young  PF  27.0  73.0  73.0  2407.0  17.5
# 24093  24093  2016.0       Cody Zeller   C  23.0  73.0  60.0  1774.0  16.1
#
# ...

# %% [markdown]
#  ## Punto 2 - Análisis detallado de un conjunto de variables

# %% [markdown]
# ### Variable de Salida: "morePoints"

# %%
my_explode = (0, 0.1)
my_colors = ['lightgreen','orange']
df['morePoints'].value_counts().plot.pie(figsize=(6, 6), fontsize=20, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors,explode=my_explode)
# Out:
# <AxesSubplot:ylabel='morePoints'>

# %% [markdown]
# Observando los datos que obtenemos del grafico anterior, podemos concluir que los jugadores, en general, logran tras cada temporada, mejorar su performance y, por ende, mejorar la cantidad de puntos que realizan a lo largo de la misma. <br><br>
# En cuanto al balanceo que se puede observar en el gráfico, podemos decir que se trata de un dataset que posee algún tipo de sesgo hacia el **"Yes"**, pero no se trata de un sesgo tan grande como para que llegue a afectar negativamente la performance del modelo o las predicciones que el mismo realice. Se podría decir, por lo tanto, que efectivamente está **desbalanceado** pero no se trata de algo tan preocupante.

# %% [markdown]
# ### Variables de Entrada

# %% [markdown]
# #### Variable Nro 1: Age (Edad)

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.scatterplot(data=df, x="Age", y="PTS", hue='PTS', style="morePoints", palette = sns.color_palette("dark:salmon_r", as_cmap=True))
# Out:
# <AxesSubplot:xlabel='Age', ylabel='PTS'>

# %% [markdown]
# En este gráfico se puede observar como en un principio (18 o 19 años) no se perciben muchos puntos, pero a medida que va avanzando la edad y no llega a una edad tan avanzada que implique que su carrera está terminando, es mas probable que el jugador realice mas anotaciones y, por lo tanto, supere las anotaciones de la temporada pasada

# %%
df_age=df.groupby(['Age','morePoints']).size()
df_age=df_age.unstack()
df_age.plot(kind='bar',figsize=(20,10),fontsize=(18))
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
auxiliarMayoresDe28 = df[df.Age >= 28]
auxiliarMenoresDe28 = df[df.Age < 28]

# %%
my_explode = (0, 0.1)
my_colors = ['#eb3434','#3aeb34']
auxiliarMayoresDe28['morePoints'].value_counts().plot.pie(figsize=(6, 6), fontsize=20, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors,explode=my_explode)
# Out:
# <AxesSubplot:ylabel='morePoints'>

# %% [markdown]
# En vistas al gráfico anterior, el cual posee los datos de los jugadores que superan los 28 años, podemos decir que a medida que un jugador llega a sus etapas finales en su carrera, su capacidad para seguir mejorando y por ende anotar mas puntos se ve reducida drásticamente, tal y como se puede observar en el gráfico que el 65.5% de dichos jugadores no es capaz de superar la cantidad de puntos que realizó la temporada anterior.

# %%
my_colors = ['#073bf5','#f5dd07']
auxiliarMenoresDe28['morePoints'].value_counts().plot.pie(figsize=(6, 6), fontsize=20, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors,explode=my_explode)
# Out:
# <AxesSubplot:ylabel='morePoints'>

# %% [markdown]
# En este caso, el gráfico nos muestra el porcentaje de jugadores menores de 28 años que si consiguieron anotar mas puntos que su temporada pasada. Se puede observar que los jugadores menores de 28 años tienen una mayor predisposicion a mejorar al siguiente año sus registros logrados en cuanto a puntos anotados.

# %% [markdown]
# #### Variable Nro 2: MP (Minutos Jugados)

# %%
jugador_d = df[df['Player'] == 'Manu Ginobili']
sns.set(rc={'figure.figsize':(15.7,12.27)})
sns.scatterplot(data=df, x="MP", y="PTS", hue='PTS', style="morePoints", palette = sns.color_palette("viridis", as_cmap=True))
# Out:
# <AxesSubplot:xlabel='MP', ylabel='PTS'>

# %% [markdown]
# En este gráfico podemos ver que a medida que el jugador permanece mas minutos en la cancha, su producción de anotaciones también aumentará. Por lo que si una temporada un jugador permaneció mucho tiempo jugando, es de esperar que la temporada siguiente se repita (o aumente sus minutos en cancha) y, en consecuencia, anote una gran cantidad de puntos, teniendo así más probabilidades de superar los puntos que realizó la temporada anterior.

# %% [markdown]
# #### Variable Nro 3: 3P% (Porcentaje de tiros de 3 puntos anotados)

# %%
auxiliarMenoresDe04 = df[df['3P%'] < 0.35]

# %%
auxiliarMenoresDe04.morePoints.value_counts().plot.bar(figsize=(6, 6))
# Out:
# <AxesSubplot:>

# %%
my_explode = (0, 0.1)
my_colors = ['#3aeb34','#eb3434']
auxiliarMenoresDe04['morePoints'].value_counts().plot.pie(figsize=(6, 6), fontsize=20, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors,explode=my_explode)
# Out:
# <AxesSubplot:ylabel='morePoints'>

# %%
auxiliarMayoresDe04 = df[df['3P%'] >= 0.35]

# %%
auxiliarMayoresDe04.morePoints.value_counts().plot.bar(figsize=(6, 6))
# Out:
# <AxesSubplot:>

# %%
auxiliarMayoresDe04['morePoints'].value_counts().plot.pie(figsize=(6, 6), fontsize=20, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors,explode=my_explode)
# Out:
# <AxesSubplot:ylabel='morePoints'>

# %% [markdown]
# En un momento supusimos que a mayor efectividad en el porcentaje de tiros de 3 puntos anotados, mayor iba a ser el porcentaje de veces que el jugador superó su marca de puntos de la temporada anterior.
# De ambos gráficos, podemos extrapolar la conclusión de que, si bien la efectividad en tiros de 3 puntos es importante a la hora de superar su marca anterior, no es una variable sumamente importante para determinar la superacion o no de la marca anterior, sino que también entran en juego las demas variables. Esto se puede concluir ya que, el porcentaje de veces que el jugador superó su marca anterior fue mayor en los casos en los que el 3P% fue menor a 0.35

# %% [markdown]
# #### Variable Nro 4: USG%

# %%
auxiliarMenoresDe25 = df[df['USG%'] < 25] 
auxiliarMenoresDe25.morePoints.value_counts().plot.bar(figsize=(6, 6))
# Out:
# <AxesSubplot:>

# %%
auxiliarMayoresDe25 = df[df['USG%'] >= 25] 
auxiliarMayoresDe25.morePoints.value_counts().plot.bar(figsize=(6, 6))
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data = df, x="USG%", y="PTS", hue='PTS', style="morePoints")
# Out:
# <AxesSubplot:xlabel='USG%', ylabel='PTS'>

# %% [markdown]
# Nuestro pensamiento previo a los cálculos coincide con lo que nos muestran los resultados graficados anteriormente. Como vimos previamente, esta estadística intenta medir la importancia de un jugador en el ataque de su equipo, por lo tanto, un jugador que tiene un mayor **"uso ofensivo" (USG%)**, muy probablemente una mayor cantidad de puntos en la temporada

# %% [markdown]
# #### Variable Nro 5: TOV% (Porcentaje de pérdidas)

# %%
sns.scatterplot(data=df, x="TOV%", y="PTS", hue='PTS', style="morePoints", palette = sns.color_palette("viridis", as_cmap=True))
# Out:
# <AxesSubplot:xlabel='TOV%', ylabel='PTS'>

# %% [markdown]
# Como se explico con anterioridad, el TOV% hace referencia a las pérdidas de la pelota cometidas por el jugador por cada 100 posesiones. Lo que nosotros intuimos antes de realizar el análisis de la variable (y que luego de realizarlos nos confirmó) es que los jugadores con un porcentaje de pérdidas muy grande (como nos indica la gráfica, una vez superado el 10% la cantidad de puntos disminuye considerablemente) son los mas propensos a realizar una menor cantidad de anotaciones, por lo que es de esperar que si un jugador tiene un TOV% muy alto, la siguiente temporada es muy probable que realice menos puntos.

# %% [markdown]
# ## Normalizacion de las variables de entrada

# %%
# En esta celda normalizamos los datos de entradas que vamos a utilizar para que así el modelo no se "incline" por alguna variable específica a la hora de entrenar.
# Optamos por el MinMaxScaler de sklearn ya que nos pareció razonable la escala entre 0 y 1 que el mismo nos proporciona.

#scaler = MinMaxScaler()
#df[['Age', 'MP', 'PER', 'ORB%', 'TOV%', 'STL%', 'OWS', 'OBPM', 'VORP', 'PTS', 'USG%']] = scaler.fit_transform(df[['Age', 'MP', 'PER', 'ORB%', 'TOV%', 'STL%', 'OWS', 'OBPM', 'VORP', 'PTS', 'USG%']])
#display(df.round(2))
# Out:
#           id    Year            Player Pos   Age     G    GS    MP   PER  \
# 5730    5730  1980.0   Tiny Archibald*  PG  0.57  80.0  80.0  0.81  0.55
# 5748    5748  1980.0       Larry Bird*  PF  0.22  82.0  82.0  0.84  0.64
# 5781    5781  1980.0         M.L. Carr  SF  0.48  82.0   7.0  0.56  0.54
# 5835    5835  1980.0        Chris Ford  SG  0.57  73.0  73.0  0.60  0.51
# 5867    5867  1980.0  Gerald Henderson  PG  0.26  76.0   2.0  0.30  0.50
# ...      ...     ...               ...  ..   ...   ...   ...   ...   ...
# 24089  24089  2016.0       James Young  SG  0.09  29.0   0.0  0.05  0.34
# 24090  24090  2016.0         Joe Young  PG  0.22  41.0   0.0  0.11  0.45
# 24091  24091  2016.0        Nick Young  SG  0.52  54.0   2.0  0.29  0.44
# 24092  24092  2016.0    Thaddeus Young  PF  0.39  73.0  73.0  0.68  0.59
# 24093  24093  2016.0       Cody Zeller   C  0.22  73.0  60.0  0.50  0.56
#
#         TS%  3PAr   FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK% morePoints  TOV%  \
# ...

# %% [markdown]
# ## Punto 3: HeatMap del dataset - Correlaciones

# %% [markdown]
# Al tener tantas variables (columnas) el dataset decidimos dividirlo en tres heatmaps diferentes, cada uno con la variable "morePoints" dentro para poder determinar si existen correlaciones fuertes entre cada una de las variables de entrada y la variable target o de salida.

# %%
df_1 = df.iloc[:,0:21]
columns = ['Player','Year','id']
df_1 = df_1.drop(columns, axis=1)
df_1.Pos = df_1.Pos.replace(['PG','SG','SF','PF','C'],[0,1,2,3,4])
df_1["morePoints"] = df_1.morePoints.replace(['No','Yes'],[0,1])

sns.heatmap(df_1.corr(),annot=True,cmap='RdYlGn',linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(25,20)
plt.show()

# %%
df_2 = df.iloc[:,21:36]
morePoints = df["morePoints"]
df_2 = df_2.join(morePoints)
df_2["morePoints"] = df_2.morePoints.replace(['No','Yes'],[0,1])

sns.heatmap(df_2.corr(),annot=True,cmap='RdYlGn',linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(25,20)
plt.show()

# %%
df_3 = df.iloc[:,36:]
morePoints = df["morePoints"]
df_3 = df_3.join(morePoints)
df_3["morePoints"] = df_3.morePoints.replace(['No','Yes'],[0,1])

sns.heatmap(df_3.corr(),annot=True,cmap='RdYlGn',linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(25,20)
plt.show()

# %% [markdown]
# Como se puede observar en los distintos gráficos, si bien para la variable target 'morePoints' existen correlaciones lineales, las mismas no son muy altas (todas entre -0.31 y 0.071). Es por esto que no vemos útil la opción de eliminar variables.
